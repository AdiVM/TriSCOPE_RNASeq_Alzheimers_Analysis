# %%
import os
import pandas as pd

# Base directories for all 4 experiments
base_dirs = {
    "demographics_only": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_demographics_seaad/",
    "genes_demographics": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/",
    "genes_apoe": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_apoe_seaad/",
    "genes_only": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_seaad/"
}

cell_types = ["Ex", "Inh", "Ast", "Mic", "Oli", "Opc"]
n_splits = 5

all_results = []

for experiment_name, base_dir in base_dirs.items():
    print(f"\n{'=' * 80}")
    print(f"EXPERIMENT: {experiment_name}")
    print(f"BASE DIR: {base_dir}")
    print(f"{'=' * 80}")

    for cell_type in cell_types:
        print(f"\n  Cell type: {cell_type}")

        for split in range(1, n_splits + 1):
            split_dir = os.path.join(base_dir, cell_type, f"split_{split}")
            output_path = os.path.join(split_dir, "output_csv.csv")

            if os.path.exists(output_path):
                try:
                    df = pd.read_csv(output_path)

                    if len(df) == 0:
                        print(f"    Split {split}: FOUND but EMPTY — {output_path}")
                        continue

                    row = df.iloc[0]

                    test_auc = row["test_roc_auc"] if "test_roc_auc" in df.columns else None
                    test_f1 = row["test_f1"] if "test_f1" in df.columns else None
                    test_mcc = row["test_mcc"] if "test_mcc" in df.columns else None

                    test_auc_str = f"{test_auc:.4f}" if pd.notnull(test_auc) else "N/A"
                    test_f1_str = f"{test_f1:.4f}" if pd.notnull(test_f1) else "N/A"
                    test_mcc_str = f"{test_mcc:.4f}" if pd.notnull(test_mcc) else "N/A"

                    print(
                        f"    Split {split}: SAVED — "
                        f"test_roc_auc = {test_auc_str}, "
                        f"test_f1 = {test_f1_str}, "
                        f"test_mcc = {test_mcc_str}"
                    )

                    result_row = {
                        "experiment": experiment_name,
                        "cell_type": cell_type,
                        "split": split,
                        "output_path": output_path
                    }

                    for col in df.columns:
                        result_row[col] = row[col]

                    all_results.append(result_row)

                except Exception as e:
                    print(f"    Split {split}: ERROR reading file — {output_path}")
                    print(f"        {e}")

            else:
                print(f"    Split {split}: MISSING — {split_dir}")
# Out:
# ...
# EXPERIMENT: demographics_only
# BASE DIR: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_demographics_seaad/
# ...
#
#   Cell type: Ex
#     Split 1: SAVED — test_roc_auc = 0.5713, test_f1 = 0.5420, test_mcc = 0.0835
#     Split 2: SAVED — test_roc_auc = 0.6085, test_f1 = 0.6536, test_mcc = 0.3003
#     Split 3: SAVED — test_roc_auc = 0.3106, test_f1 = 0.2037, test_mcc = -0.5688
#     Split 4: SAVED — test_roc_auc = 0.5263, test_f1 = 0.5942, test_mcc = -0.1207
#     Split 5: SAVED — test_roc_auc = 0.5375, test_f1 = 0.4176, test_mcc = 0.0456
#
#   Cell type: Inh
#     Split 1: SAVED — test_roc_auc = 0.5918, test_f1 = 0.5988, test_mcc = 0.1284
#     Split 2: SAVED — test_roc_auc = 0.7011, test_f1 = 0.7171, test_mcc = 0.3924
#     Split 3: SAVED — test_roc_auc = 0.5190, test_f1 = 0.5079, test_mcc = -0.0360
#     Split 4: SAVED — test_roc_auc = 0.4480, test_f1 = 0.5183, test_mcc = 0.0287
#     Split 5: SAVED — test_roc_auc = 0.5381, test_f1 = 0.6569, test_mcc = 0.2662
# ...

# %%
import os
import pandas as pd

# Base directories for all 4 experiments
base_dirs = {
    "demographics_only": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_demographics_seaad/",
    "genes_demographics": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/",
    "genes_apoe": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_apoe_seaad/",
    "genes_only": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_seaad/"
}

cell_types = ["Ex", "Inh", "Ast", "Mic", "Oli", "Opc"]
n_splits = 5

all_results = []

for experiment_name, base_dir in base_dirs.items():
    print(f"\n{'=' * 80}")
    print(f"EXPERIMENT: {experiment_name}")
    print(f"BASE DIR: {base_dir}")
    print(f"{'=' * 80}")

    for cell_type in cell_types:
        print(f"\n  Cell type: {cell_type}")

        for split in range(1, n_splits + 1):
            split_dir = os.path.join(base_dir, cell_type, f"split_{split}")
            output_path = os.path.join(split_dir, "output_csv.csv")

            if os.path.exists(output_path):
                try:
                    df = pd.read_csv(output_path)

                    if len(df) == 0:
                        print(f"    Split {split}: FOUND but EMPTY — {output_path}")
                        continue

                    row = df.iloc[0]

                    test_auc = row["test_roc_auc"] if "test_roc_auc" in df.columns else None
                    test_f1 = row["test_f1"] if "test_f1" in df.columns else None
                    test_mcc = row["test_mcc"] if "test_mcc" in df.columns else None

                    test_auc_str = f"{test_auc:.4f}" if pd.notnull(test_auc) else "N/A"
                    test_f1_str = f"{test_f1:.4f}" if pd.notnull(test_f1) else "N/A"
                    test_mcc_str = f"{test_mcc:.4f}" if pd.notnull(test_mcc) else "N/A"

                    print(
                        f"    Split {split}: SAVED — "
                        f"test_roc_auc = {test_auc_str}, "
                        f"test_f1 = {test_f1_str}, "
                        f"test_mcc = {test_mcc_str}"
                    )

                    result_row = {
                        "experiment": experiment_name,
                        "cell_type": cell_type,
                        "split": split,
                        "output_path": output_path
                    }

                    for col in df.columns:
                        result_row[col] = row[col]

                    all_results.append(result_row)

                except Exception as e:
                    print(f"    Split {split}: ERROR reading file — {output_path}")
                    print(f"        {e}")

            else:
                print(f"    Split {split}: MISSING — {split_dir}")
# Out:
# ...
# EXPERIMENT: demographics_only
# BASE DIR: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_demographics_seaad/
# ...
#
#   Cell type: Ex
#     Split 1: SAVED — test_roc_auc = 0.5713, test_f1 = 0.5420, test_mcc = 0.0835
#     Split 2: SAVED — test_roc_auc = 0.6085, test_f1 = 0.6536, test_mcc = 0.3003
#     Split 3: SAVED — test_roc_auc = 0.3106, test_f1 = 0.2037, test_mcc = -0.5688
#     Split 4: SAVED — test_roc_auc = 0.5263, test_f1 = 0.5942, test_mcc = -0.1207
#     Split 5: SAVED — test_roc_auc = 0.5375, test_f1 = 0.4176, test_mcc = 0.0456
#
#   Cell type: Inh
#     Split 1: SAVED — test_roc_auc = 0.5918, test_f1 = 0.5988, test_mcc = 0.1284
#     Split 2: SAVED — test_roc_auc = 0.7011, test_f1 = 0.7171, test_mcc = 0.3924
#     Split 3: SAVED — test_roc_auc = 0.5190, test_f1 = 0.5079, test_mcc = -0.0360
#     Split 4: SAVED — test_roc_auc = 0.4480, test_f1 = 0.5183, test_mcc = 0.0287
#     Split 5: SAVED — test_roc_auc = 0.5381, test_f1 = 0.6569, test_mcc = 0.2662
# ...

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curves_with_variability(cell_type, cell_name):
    base_dirs = {
        'Demographics': f'/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_demographics_seaad/{cell_type}',
        'Genes + Demographics': f'/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/{cell_type}',
        'Genes + APOE': f'/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_apoe_seaad/{cell_type}',
        'Genes Only': f'/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_seaad/{cell_type}',
    }

    colors = {
        'Demographics': 'black',
        'Genes + Demographics': 'blue',
        'Genes + APOE': 'red',
        'Genes Only': '#66c2a5',
    }

    plt.figure(figsize=(8, 6))
    mean_fpr = np.linspace(0, 1, 100)

    for label, base_path in base_dirs.items():
        all_tprs = []
        aucs = []

        for i in range(1, 6):
            pred_file = os.path.join(base_path, f'split_{i}', 'test_predictions.csv')
            if not os.path.exists(pred_file):
                print(f"Missing: {label} | Split {i} | Path: {pred_file}")
                continue

            df = pd.read_csv(pred_file)
            y_true = df['true_label']
            y_score = df['predicted_proba']
            fpr, tpr, _ = roc_curve(y_true, y_score)
            interp_tpr = np.interp(mean_fpr, fpr, tpr)
            interp_tpr[0] = 0.0
            all_tprs.append(interp_tpr)
            aucs.append(auc(fpr, tpr))

            plt.plot(fpr, tpr, color=colors[label], alpha=0.2)

        if all_tprs:
            mean_tpr = np.mean(all_tprs, axis=0)
            mean_auc = np.mean(aucs)
            std_auc = np.std(aucs)
            plt.plot(mean_fpr, mean_tpr, color=colors[label], linewidth=2.5,
                     label=f'{label} (AUC: {mean_auc:.3f} ± {std_auc:.3f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold')
    plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold')
    plt.title(cell_name, fontsize=16, fontweight='bold')
    plt.xticks(fontsize=12, fontweight='bold')
    plt.yticks(fontsize=12, fontweight='bold')
    plt.legend(loc='lower right', fontsize=11, frameon=True)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_roc_curves_with_variability('Mic', 'Microglia')
plot_roc_curves_with_variability('Ast', 'Astrocytes')
plot_roc_curves_with_variability('Inh', 'Inhibitory Neurons')
plot_roc_curves_with_variability('Ex', 'Excitatory Neurons')
plot_roc_curves_with_variability('Opc', 'Oligodendrocyte Progenitor Cells')
plot_roc_curves_with_variability('Oli', 'Oligodendrocytes')
# Out:
# Missing: Genes + Demographics | Split 1 | Path: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/Ast/split_1/test_predictions.csv
# Missing: Genes + Demographics | Split 2 | Path: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/Ast/split_2/test_predictions.csv
# Missing: Genes + Demographics | Split 3 | Path: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/Ast/split_3/test_predictions.csv
# Missing: Genes + Demographics | Split 4 | Path: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/Ast/split_4/test_predictions.csv
# Missing: Genes + Demographics | Split 5 | Path: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad/Ast/split_5/test_predictions.csv
# ...

# %%
import os
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

# === Paths ===
base_dirs = {
    "Combined": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_both_new",
    "Genes + Demographics": "/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_genes_demographics_seaad"
}

# === Cell type labels ===
ct_labels = {
    'Mic': 'Microglia',
    'Ast': 'Astrocytes',
    'Inh': 'Inhibitory Neurons',
    'Oli': 'Oligodendrocytes',
    'Opc': 'Oligodendrocyte Progenitor Cells',
    'Ex': 'Excitatory Neurons'
}

cell_types = list(ct_labels.keys())

# === Plotting function ===
def plot_feature_importance(features_df, cell_name, exp_name, top_n=10):
    df_sorted = features_df.sort_values(by="Filtered_Mean", ascending=False).head(top_n)

    genes = df_sorted["Feature"]
    means = df_sorted["Filtered_Mean"]

    plt.figure(figsize=(5, 6))
    plt.barh(range(len(genes)), means, color="skyblue", edgecolor="black")
    plt.yticks(range(len(genes)), genes, fontsize=9)
    plt.xlabel("Normalized Feature Importance", fontsize=11)
    plt.title(f"{cell_name} ({exp_name})", fontsize=14, fontweight="bold")
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()

# === Main loop ===
for exp_name, base_dir in base_dirs.items():
    print(f"\n{'='*60}")
    print(f"EXPERIMENT: {exp_name}")
    print(f"{'='*60}")

    for cell_type in cell_types:
        print(f"Processing: {cell_type}")

        all_split_data = {}
        all_features = set()

        for split in range(1, 6):
            joblib_path = os.path.join(base_dir, cell_type, f"split_{split}", "maximal_classifier.joblib")

            if not os.path.exists(joblib_path):
                print(f"  Missing: {joblib_path}")
                all_split_data[split] = {}
                continue

            model = joblib.load(joblib_path)

            feature_names = model.feature_names_in_
            importances = model.feature_importances_

            all_features.update(feature_names)
            all_split_data[split] = dict(zip(feature_names, importances))

        # Build dataframe
        table_rows = []

        for feature in sorted(list(all_features)):
            filtered_norm_values = []

            for split in range(1, 6):
                raw_imp = all_split_data.get(split, {}).get(feature, 0.0)

                all_imps_in_split = np.array(list(all_split_data.get(split, {}).values()))
                total_nonzero_imp = np.nansum(all_imps_in_split[all_imps_in_split > 0])

                if raw_imp > 0 and total_nonzero_imp > 0:
                    norm_imp = raw_imp / total_nonzero_imp
                else:
                    norm_imp = 0.0

                filtered_norm_values.append(norm_imp)

            row_data = {
                "Feature": feature,
                "Filtered_Mean": np.mean(filtered_norm_values),
                "Filtered_Std": np.std(filtered_norm_values) / np.sqrt(len(filtered_norm_values))
            }

            table_rows.append(row_data)

        features_df = pd.DataFrame(table_rows)

        if not features_df.empty:
            plot_feature_importance(features_df, ct_labels[cell_type], exp_name, top_n=10)

print("Done.")
# Out:
# ...
# EXPERIMENT: Combined
# ...
# Processing: Mic
# Processing: Ast
# Processing: Inh
#   Missing: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_both_new/Inh/split_1/maximal_classifier.joblib
#   Missing: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_both_new/Inh/split_2/maximal_classifier.joblib
#   Missing: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_both_new/Inh/split_3/maximal_classifier.joblib
#   Missing: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_both_new/Inh/split_4/maximal_classifier.joblib
#   Missing: /n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Multirun_cell_on_cell_both_new/Inh/split_5/maximal_classifier.joblib
# Processing: Oli
# Processing: Opc
# Processing: Ex
# ...
# EXPERIMENT: Genes + Demographics
# ...
# Processing: Mic
# Processing: Ast
# ...
